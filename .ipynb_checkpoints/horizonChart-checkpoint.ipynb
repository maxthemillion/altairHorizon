# %% [markdown]
# # Horizon Chart with Altair

# %% [markdown]
# ## Imports

# %%
from horizonChart.horizonChart import HorizonChartGenerator as hcg
from altairThemes.standardTheme import standardTheme

# %%
import pandas as pd
import altair as alt
import numpy as np

# %%
alt.themes.register("standardTheme", standardTheme)
alt.themes.enable("standardTheme")
# Out:
# ThemeRegistry.enable('standardTheme')

# %% [markdown]
# ## Data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/maxthemillion/visualizingSales/master/data/sales_day.csv')
df.date = pd.to_datetime(df.date)

# %%
df = df.loc[(df.date>='2015-02-01') & 
            (df.date<='2015-03-31') & 
            (df.shop_id > 1) & 
            (~df.shop_id.isin([12, 9, 17, 20, 43, 10, 30, 40, 49, 50])), :]
len(df)
# Out:
# 2269

# %%
grouped = df.groupby([pd.Grouper(key='shop_id'), pd.Grouper(key='date')]).sum()

# %%
for i in grouped.index.levels[0]:
    grouped.loc[i, 'index_base'] = grouped.loc[i,'revenue'][1]
    grouped.loc[i, 'm'] = np.median(grouped.loc[i, 'revenue'])

# %%
grouped['index'] = grouped.apply((lambda x: (x.revenue - x.index_base)/x.index_base), axis=1)
grouped['rel_median'] = grouped.apply((lambda x: (x.revenue - x.m)/(x.m)), axis=1)

# %%
grouped = grouped.reset_index()

# %% [markdown]
# ## Sample plot

# %%
r = hcg(data=grouped, X='date', Y='rel_median', noLevels=4).generate()

# %%
r.properties(
    width=700,
    height=20
).facet(
    row=alt.Row('shop_id:O', title='Shop id')
).properties(
    title="Development of Sales Revenue per Shop relative to each shop's median revenue"
).configure_facet(
    spacing=4
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(df).mark_bar().encode(
    alt.X('date:T'),
    alt.Y('item_cnt_day:Q'),
    row='shop_id:O'
)
# Out:
# ------------------------------------------------------------------
# MaxRowsError                     Traceback (most recent call last)
# /anaconda3/envs/viz/lib/python3.7/site-packages/altair/vegalite/v3/api.py in to_dict(self, *args, **kwargs)
#     363         copy = self.copy(deep=False)
#     364         original_data = getattr(copy, 'data', Undefined)
# --> 365         copy.data = _prepare_data(original_data, context)
#     366
#     367         if original_data is not Undefined:
#
# /anaconda3/envs/viz/lib/python3.7/site-packages/altair/vegalite/v3/api.py in _prepare_data(data, context)
#      82     # convert dataframes to dict
#      83     if isinstance(data, pd.DataFrame):
# ---> 84         data = pipe(data, data_transformers.get())
#      85
#      86     # convert string input to a URLData
#
# /anaconda3/envs/viz/lib/python3.7/site-packages/toolz/functoolz.py in pipe(data, *funcs)
#     632     """
#     633     for func in funcs:
# --> 634         data = func(data)
#     635     return data
#     636
#
# /anaconda3/envs/viz/lib/python3.7/site-packages/toolz/functoolz.py in __call__(self, *args, **kwargs)
#     301     def __call__(self, *args, **kwargs):
#     302         try:
# --> 303             return self._partial(*args, **kwargs)
#     304         except TypeError as exc:
#     305             if self._should_curry(args, kwargs, exc):
#
# /anaconda3/envs/viz/lib/python3.7/site-packages/altair/vegalite/data.py in default_data_transformer(data, max_rows)
#      11 @curry
#      12 def default_data_transformer(data, max_rows=5000):
# ---> 13     return pipe(data, limit_rows(max_rows=max_rows), to_values)
#      14
#      15
#
# /anaconda3/envs/viz/lib/python3.7/site-packages/toolz/functoolz.py in pipe(data, *funcs)
#     632     """
#     633     for func in funcs:
# --> 634         data = func(data)
#     635     return data
#     636
#
# /anaconda3/envs/viz/lib/python3.7/site-packages/toolz/functoolz.py in __call__(self, *args, **kwargs)
#     301     def __call__(self, *args, **kwargs):
#     302         try:
# --> 303             return self._partial(*args, **kwargs)
#     304         except TypeError as exc:
#     305             if self._should_curry(args, kwargs, exc):
#
# /anaconda3/envs/viz/lib/python3.7/site-packages/altair/utils/data.py in limit_rows(data, max_rows)
#      70                            'than the maximum allowed ({}). '
#      71                            'For information on how to plot larger datasets '
# ---> 72                            'in Altair, see the documentation'.format(max_rows))
#      73     return data
#      74
#
# MaxRowsError: The number of rows in your dataset is greater than the maximum allowed (5000). For information on how to plot larger datasets in Altair, see the documentation
# alt.Chart(...)
